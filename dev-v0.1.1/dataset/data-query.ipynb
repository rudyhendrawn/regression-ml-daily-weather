# %%
import pandas as pd
import peramalan_cuaca_bmkg_dev.data_processor as data_processor
import peramalan_cuaca_bmkg_dev.data_query as data_query
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2059/2086463949.py in <module>
#       1 import pandas as pd
# ----> 2 import peramalan_cuaca_bmkg_dev.data_processor as data_processor
#       3 import peramalan_cuaca_bmkg_dev.data_query as data_query
#
# ~/Codes/Python/streamlit/peramalan_cuaca_bmkg_dev/data_processor.py in <module>
#       3 import pandas as pd
#       4 from pandas.core.frame import DataFrame
# ----> 5 import data_query
#       6
#       7 dataframe = data_query.get_train_data()
#
# ModuleNotFoundError: No module named 'data_query'

# %%
df = pd.read_csv('peramalan_cuaca_bmkg_dev/dataset/fklim-ngrai-20112020-final.csv')
df.head()
# Out:
#        Date  Tahun  Bulan  Tanggal  T0700  T1300  T1800  Trata-rata  Tmax  \
# 0  1/1/2011   2011      1        1   25.1   27.0   26.4        25.9  29.0
# 1  2/1/2011   2011      1        2   26.4   30.6   26.9        27.6  30.6
# 2  3/1/2011   2011      1        3   25.4   30.3   26.0        26.8  31.2
# 3  4/1/2011   2011      1        4   25.2   28.6   28.3        26.8  29.5
# 4  5/1/2011   2011      1        5   24.6   30.8   27.2        26.8  31.7
#
#    Tmin  ...     QFE  RH0700 RH1300  RH1800  RHrata-rata  ffrata-rata   dd  \
# 0  24.7  ...  1004.1      95     90      86           92            3   90
# 1  25.5  ...  1005.9      86     75      90           84            4  320
# 2  24.8  ...  1005.6      93     77      91           89            3   90
# 3  24.4  ...  1005.6      93     82      75           86            4  270
# 4  24.1  ...  1005.3      88     72      89           84            3   50
#
#    ffmax  ddmax  QFF
# 0    8.0     70  NaN
# 1   12.0    290  NaN
# ...

# %%
df_train, dt_test = data_processor.split_dataset(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_621/4013168905.py in <module>
# ----> 1 df_train, dt_test = data_processor.split_dataset(df)
#
# NameError: name 'data_processor' is not defined
